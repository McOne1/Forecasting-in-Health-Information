# %%
from tkinter import *
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

l1=['sweating','pallor','vomiting','muscle and joint pain','neck stiffness','decreased consciousness','headache','fever']
disease=['malaria','dengue','meningitis']

l2=[]
for x in range(0,len(l1)):
    l2.append(0)

# %%
df=pd.read_csv("ptrain.csv")

df.replace({'prognosis':{'malaria':0,'dengue':1,'meningitis':2}},inplace=True)


X = df[l1]

y = df[["prognosis"]]
y = np.ravel(y)

# %%
tr=pd.read_csv("ptest.csv")
tr.replace({'prognosis':{'malaria':0,'dengue':1,'meningitis':2}},inplace=True)

X_test= tr[l1]
y_test = tr[["prognosis"]]
y_test = np.ravel(y_test)

# %%
def DecisionTree():

    from sklearn import tree

    clf3 = tree.DecisionTreeClassifier()   # empty model of the decision tree
    clf3 = clf3.fit(X,y)

    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score
    
    y_pred=clf3.predict(X_test)
    print(accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred,normalize=False))
    
    from sklearn.metrics import confusion_matrix
    confusion_matrix(y_test,y_pred )
    
    # -----------------------------------------------------

    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get()]

    for k in range(0,len(l1)):
        # print (k,)
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1

    inputtest = [l2]
    predict = clf3.predict(inputtest)
    predicted=predict[0]

    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break

    if (h=='yes'):
        t1.delete("1.0", END)
        t1.insert(END, disease[a])
    else:
        t1.delete("1.0", END)
        t1.insert(END, "Not Found")
        
def randomforest():
     
    from sklearn.ensemble import RandomForestClassifier
    clf4 = RandomForestClassifier()
    clf4.fit(X,np.ravel(y))
    
    from sklearn.metrics import accuracy_score
    y_pred=clf4.predict(X_test)
    print(accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred,normalize=False))
    # -----------------------------------------------------

    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(), Symptom4.get()]

    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1

    inputtest = [l2]
    predict = clf4.predict(inputtest)
    predicted=predict[0]

    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break
    
    if (h=='yes'):
        t2.delete("1.0", END)
        t2.insert(END, disease[a])
    else:
        t2.delete("1.0", END)
        t2.insert(END, "Not Found")

# %%
def malaria_window():
    top= Toplevel()
    top.title('Check Malaria Symptoms')
    
    dataset= pd.read_csv('malariaF.csv')
    dataset.dropna(inplace=True)  
    X_mal= dataset.iloc[:,0:-1].values
    y_mal= dataset.iloc[:,11].values

    
    X_train_mal, X_test_mal, y_train_mal, y_test_mal= train_test_split(X_mal, y_mal, test_size=0.2, random_state=0)
    
    sc= StandardScaler()
    X_train_mal= sc.fit_transform(X_train_mal)
    

    classifier= tf.keras.Sequential([
    tf.keras.layers.Dense(6, kernel_initializer='uniform', activation='relu',input_dim=11),
    tf.keras.layers.Dense(6, kernel_initializer='uniform', activation='relu'),
    tf.keras.layers.Dense(1, kernel_initializer='uniform', activation='sigmoid')])    
    classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    classifier.fit(X_train_mal, y_train_mal,validation_split=0.33, epochs=75, batch_size=10)
    
    def classify(input):
        y_pred= classifier.predict(input)
        return y_pred
    
    s1= Label(top, text="Recurrent Fever", fg="black")
    s1.grid(row=1, column=1)
    s1txt= Entry(top, fg="black")
    s1txt.grid(row=1, column=2)
    s1txt.insert(0,"Enter Value")
    
    s2= Label(top, text="Chills", fg="black")
    s2.grid(row=2, column=1)
    s2txt= Entry(top, fg="black")
    s2txt.grid(row=2, column=2)
    s2txt.insert(0,"Enter Value")
    
    s3= Label(top, text="Sweating", fg="black")
    s3.grid(row=3, column=1)
    s3txt= Entry(top, fg="black")
    s3txt.grid(row=3, column=2)
    s3txt.insert(0,"Enter Value")
    
    s4= Label(top, text="Vomiting", fg="black")
    s4.grid(row=4, column=1)
    s4txt= Entry(top, fg="black")
    s4txt.grid(row=4, column=2)
    s4txt.insert(0,"Enter Value")
    
    s5= Label(top, text="Pallor", fg="black")
    s5.grid(row=5, column=1)
    s5txt= Entry(top, fg="black")
    s5txt.grid(row=5, column=2)
    s5txt.insert(0,"Enter Value")
    
    s6= Label(top, text="Headache", fg="black")
    s6.grid(row=6, column=1)
    s6txt= Entry(top, fg="black")
    s6txt.grid(row=6, column=2)
    s6txt.insert(0,"Enter Value")
    
    s7= Label(top, text="Abdomen Pain", fg="black")
    s7.grid(row=7, column=1)
    s7txt= Entry(top, fg="black")
    s7txt.grid(row=7, column=2)
    s7txt.insert(0,"Enter Value")
    
    s8= Label(top, text="Fatigue", fg="black")
    s8.grid(row=8, column=1)
    s8txt= Entry(top, fg="black")
    s8txt.grid(row=8, column=2)
    s8txt.insert(0,"Enter Value")
    
    s9= Label(top, text="Weight Loss", fg="black")
    s9.grid(row=9, column=1)
    s9txt= Entry(top, fg="black")
    s9txt.grid(row=9, column=2)
    s9txt.insert(0,"Enter Value")
    
    s10= Label(top, text="Breathlessness", fg="black")
    s10.grid(row=10, column=1)
    s10txt= Entry(top, fg="black")
    s10txt.grid(row=10, column=2)
    s10txt.insert(0,"Enter Value")
    
    s11= Label(top, text="Oedema", fg="black")
    s11.grid(row=11, column=1)
    s11txt= Entry(top, fg="black")
    s11txt.grid(row=11, column=2)
    s11txt.insert(0,"Enter Value")
    
    def cominput():
        new_data= pd.DataFrame({'recurrent fever':[float(s1txt.get())],'chills':[float(s2txt.get())],'sweating':[float(s3txt.get())],'vomiting':[float(s4txt.get())],'pallor':[float(s5txt.get())],'headache':[float(s6txt.get())],'abdomen pain':[float(s7txt.get())],'fatigue':[float(s8txt.get())],'weight loss':[float(s9txt.get())],'breathlessness':[float(s10txt.get())],'oedema':[float(s11txt.get())]})
        input= new_data.iloc[:,0:11].values
        result=float(classify(input))
        show= Label(top, text= result, fg="black")
        show.grid(row=13, column=1)
        
    submit= Button(top, text="Submit", command= cominput, fg="white", bg="blue")
    submit.grid(row=13, column=2)
    

    
    
def dengue_window():
    top= Toplevel()
    top.title('Check Dengue Symptoms')
    
    dataset= pd.read_csv('dengue2.csv')
    
    X= dataset.iloc[:,0:-1].values
    y= dataset.iloc[:,10].values

    
    X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=0)

    
    sc= StandardScaler()
    X_train= sc.fit_transform(X_train)
    
    classifier= tf.keras.Sequential([
    tf.keras.layers.Dense(6, kernel_initializer='uniform', activation='relu',input_dim=10),
    tf.keras.layers.Dense(6, kernel_initializer='uniform', activation='relu'),
    tf.keras.layers.Dense(1, kernel_initializer='uniform', activation='sigmoid')])    
    classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    classifier.fit(X_train, y_train,validation_split=0.33, epochs=75, batch_size=10)

    def classify(input):
        y_pred= classifier.predict(input)
        return y_pred
    
    s1= Label(top, text="High Fever", fg="black")
    s1.grid(row=1, column=1)
    s1txt= Entry(top, fg="black")
    s1txt.grid(row=1, column=2)
    s1txt.insert(0,"Enter Value")
    
    s2= Label(top, text="Headache", fg="black")
    s2.grid(row=2, column=1)
    s2txt= Entry(top, fg="black")
    s2txt.grid(row=2, column=2)
    s2txt.insert(0,"Enter Value")
    
    s3= Label(top, text="Muscle and Joint pain", fg="black")
    s3.grid(row=3, column=1)
    s3txt= Entry(top, fg="black")
    s3txt.grid(row=3, column=2)
    s3txt.insert(0,"Enter Value")
    
    s4= Label(top, text="Pain behind eyes", fg="black")
    s4.grid(row=4, column=1)
    s4txt= Entry(top, fg="black")
    s4txt.grid(row=4, column=2)
    s4txt.insert(0,"Enter Value")
    
    s5= Label(top, text="Rashes", fg="black")
    s5.grid(row=5, column=1)
    s5txt= Entry(top, fg="black")
    s5txt.grid(row=5, column=2)
    s5txt.insert(0,"Enter Value")
    
    s6= Label(top, text="Vomiting", fg="black")
    s6.grid(row=6, column=1)
    s6txt= Entry(top, fg="black")
    s6txt.grid(row=6, column=2)
    s6txt.insert(0,"Enter Value")
    
    s7= Label(top, text="Abdominal Pain", fg="black")
    s7.grid(row=7, column=1)
    s7txt= Entry(top, fg="black")
    s7txt.grid(row=7, column=2)
    s7txt.insert(0,"Enter Value")
    
    s8= Label(top, text="Cyanosis", fg="black")
    s8.grid(row=8, column=1)
    s8txt= Entry(top, fg="black")
    s8txt.grid(row=8, column=2)
    s8txt.insert(0,"Enter Value")
    
    s9= Label(top, text="Oedema", fg="black")
    s9.grid(row=9, column=1)
    s9txt= Entry(top, fg="black")
    s9txt.grid(row=9, column=2)
    s9txt.insert(0,"Enter Value")
    
    s10= Label(top, text="Facial Puffiness", fg="black")
    s10.grid(row=10, column=1)
    s10txt= Entry(top, fg="black")
    s10txt.grid(row=10, column=2)
    s10txt.insert(0,"Enter Value")
    
    
    def cominput():
        new_data= pd.DataFrame({'High Fever':[float(s1txt.get())],'Headache':[float(s2txt.get())],'Muscle and Joint pain':[float(s3txt.get())],'Pain behind eyes':[float(s4txt.get())],'Rashes':[float(s5txt.get())],'Vomiting':[float(s6txt.get())],'Abdominal Pain':[float(s7txt.get())],'Cyanosis':[float(s8txt.get())],'Oedema':[float(s9txt.get())],'Facial Puffiness':[float(s10txt.get())]})
        input= new_data.iloc[:,0:10].values
        result=float(classify(input))
        show= Label(top, text= result, fg="black")
        show.grid(row=12, column=1)
        
    submit= Button(top, text="Submit", command= cominput, fg="white", bg="blue")
    submit.grid(row=12, column=2)
    
def meningitis_window():
    top= Toplevel()
    top.title('Check Meningitis Symptoms')
    dataset= pd.read_csv('meningitis.csv')
    dataset.drop(inplace=True )
    X= dataset.iloc[:,0:-1].values
    y= dataset.iloc[:,13].values

    X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=0)

    sc= StandardScaler()
    X_train= sc.fit_transform(X_train)
    
    classifier= tf.keras.Sequential([
    tf.keras.layers.Dense(6, kernel_initializer='uniform', activation='relu', input_dim=13),
    tf.keras.layers.Dense(6, kernel_initializer='uniform', activation='relu'),
    tf.keras.layers.Dense(1, kernel_initializer='uniform', activation='sigmoid')])

    classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    classifier.fit(X_train, y_train, validation_split=0.33, epochs=75, batch_size=10)
    
    s1= Label(top, text="Decreased Consciousness", fg="black")
    s1.grid(row=1, column=1)
    s1txt= Entry(top, fg="black")
    s1txt.grid(row=1, column=2)
    s1txt.insert(0,"Enter Value")
    
    s2= Label(top, text="Fever", fg="black")
    s2.grid(row=2, column=1)
    s2txt= Entry(top, fg="black")
    s2txt.grid(row=2, column=2)
    s2txt.insert(0,"Enter Value")
    
    s3= Label(top, text="Headache", fg="black")
    s3.grid(row=3, column=1)
    s3txt= Entry(top, fg="black")
    s3txt.grid(row=3, column=2)
    s3txt.insert(0,"Enter Value")
    
    s4= Label(top, text="Vomiting", fg="black")
    s4.grid(row=4, column=1)
    s4txt= Entry(top, fg="black")
    s4txt.grid(row=4, column=2)
    s4txt.insert(0,"Enter Value")
    
    s5= Label(top, text="Neck Stiffness", fg="black")
    s5.grid(row=5, column=1)
    s5txt= Entry(top, fg="black")
    s5txt.grid(row=5, column=2)
    s5txt.insert(0,"Enter Value")
    
    s6= Label(top, text="Blurred Vision", fg="black")
    s6.grid(row=6, column=1)
    s6txt= Entry(top, fg="black")
    s6txt.grid(row=6, column=2)
    s6txt.insert(0,"Enter Value")
    
    s7= Label(top, text="Behavioral Changes", fg="black")
    s7.grid(row=7, column=1)
    s7txt= Entry(top, fg="black")
    s7txt.grid(row=7, column=2)
    s7txt.insert(0,"Enter Value")
    
    s8= Label(top, text="Weakness in Limbs", fg="black")
    s8.grid(row=8, column=1)
    s8txt= Entry(top, fg="black")
    s8txt.grid(row=8, column=2)
    s8txt.insert(0,"Enter Value")
    
    s9= Label(top, text="Tingling", fg="black")
    s9.grid(row=9, column=1)
    s9txt= Entry(top, fg="black")
    s9txt.grid(row=9, column=2)
    s9txt.insert(0,"Enter Value")
    
    s10= Label(top, text="Syncope", fg="black")
    s10.grid(row=10, column=1)
    s10txt= Entry(top, fg="black")
    s10txt.grid(row=10, column=2)
    s10txt.insert(0,"Enter Value")
    
    s11= Label(top, text="Pain in Neck", fg="black")
    s11.grid(row=11, column=1)
    s11txt= Entry(top, fg="black")
    s11txt.grid(row=11, column=2)
    s11txt.insert(0,"Enter Value")
    
    s12= Label(top, text="Convulsion", fg="black")
    s12.grid(row=12, column=1)
    s12txt= Entry(top, fg="black")
    s12txt.grid(row=12, column=2)
    s12txt.insert(0,"Enter Value")
    
    s13= Label(top, text="Speech Defects", fg="black")
    s13.grid(row=13, column=1)
    s13txt= Entry(top, fg="black")
    s13txt.grid(row=13, column=2)
    s13txt.insert(0,"Enter Value")
    
    def cominput():
        new_data= pd.DataFrame({'decreased consciousness':[float(s1txt.get())],'fever':[float(s2txt.get())],'headache':[float(s3txt.get())],'vomiting':[float(s4txt.get())],'neck stiffness':[float(s5txt.get())],'blurred vision':[float(s6txt.get())],'behavioral changes':[float(s7txt.get())],'weakness in limbs':[float(s8txt.get())],'tingling':[float(s9txt.get())],'syncope':[float(s10txt.get())],'pain in neck':[float(s11txt.get())],'convulsion':[float(s12txt.get())],'speech defects':[float(s13txt.get())]})
        input= new_data.iloc[:,0:13].values
        result=float(classify(input))
        show= Label(top, text= result, fg="black")
        show.grid(row=15, column=1)
        
    submit= Button(top, text="Submit", command= cominput, fg="white", bg="blue")
    submit.grid(row=15, column=2)
    
    
import tkinter
root = Tk()
root.configure(background='light blue')

# entry variables
Symptom1 = StringVar()
Symptom1.set(None)
Symptom2 = StringVar()
Symptom2.set(None)
Symptom3 = StringVar()
Symptom3.set(None)
Symptom4 = StringVar()
Symptom4.set(None)

# Heading
w2 = Label(root, justify=LEFT, text="Disease Predictor using Machine Learning", fg="white", bg="blue")
w2.config(font=("Elephant", 30))
w2.grid(row=1, column=0, columnspan=2, padx=100)
w2 = Label(root, justify=LEFT, text="Final project", fg="white", bg="grey")
w2.config(font=("Aharoni", 30))
w2.grid(row=2, column=0, columnspan=2, padx=100)

# labels
NameLb = Label(root, text="Name of the Patient", fg="yellow", bg="black")
NameLb.grid(row=6, column=0, pady=15, sticky=W)


S1Lb = Label(root, text="Symptom 1", fg="yellow", bg="blue")
S1Lb.grid(row=7, column=0, pady=10, sticky=W)

S2Lb = Label(root, text="Symptom 2", fg="yellow", bg="blue")
S2Lb.grid(row=8, column=0, pady=10, sticky=W)

S3Lb = Label(root, text="Symptom 3", fg="yellow", bg="blue")
S3Lb.grid(row=9, column=0, pady=10, sticky=W)

S4Lb = Label(root, text="Symptom 4", fg="yellow", bg="blue")
S4Lb.grid(row=10, column=0, pady=10, sticky=W)

lrLb = Label(root, text="DecisionTree", fg="white", bg="grey")
lrLb.grid(row=15, column=0, pady=10,sticky=W)

destreeLb = Label(root, text="RandomForest", fg="white", bg="grey")
destreeLb.grid(row=17, column=0, pady=10, sticky=W)

button1= Button(root, text="Check Accuracy of Malaria", command=malaria_window, bg= "green", fg= "white")
button1.grid(row= 15, column=2)

button2= Button(root, text="Check Accuracy of Dengue", command=dengue_window, bg= "green", fg= "white")
button2.grid(row= 16, column=2)

button3= Button(root, text="Check Accuracy of Meningitis", command=meningitis_window, bg= "green", fg= "white")
button3.grid(row= 17, column=2)

# entries
OPTIONS = sorted(l1)

NameEn = Entry(root)
NameEn.grid(row=6, column=1)

S1En = OptionMenu(root, Symptom1,*OPTIONS)
S1En.grid(row=7, column=1)

S2En = OptionMenu(root, Symptom2,*OPTIONS)
S2En.grid(row=8, column=1)

S3En = OptionMenu(root, Symptom3,*OPTIONS)
S3En.grid(row=9, column=1)

S4En = OptionMenu(root, Symptom4,*OPTIONS)
S4En.grid(row=10, column=1)

dst = Button(root, text="DecisionTree", command=DecisionTree,bg="green",fg="yellow")
dst.grid(row=8, column=3,padx=10)

rnf = Button(root, text="Randomforest", command=randomforest,bg="green",fg="yellow")
rnf.grid(row=9, column=3,padx=10)

#textfileds
t1 = Text(root, height=1, width=40,bg="orange",fg="black")
t1.grid(row=15, column=1, padx=10)

t2 = Text(root, height=1, width=40,bg="orange",fg="black")
t2.grid(row=17, column=1 , padx=10)


root.mainloop()
# Out:
# Train on 109 samples, validate on 55 samples
# Epoch 1/75
# 109/109 [==============================] - 1s 8ms/sample - loss: 0.6931 - accuracy: 0.5413 - val_loss: 0.6928 - val_accuracy: 0.5455
# Epoch 2/75
# 109/109 [==============================] - 0s 247us/sample - loss: 0.6924 - accuracy: 0.5413 - val_loss: 0.6921 - val_accuracy: 0.5455
# Epoch 3/75
# 109/109 [==============================] - 0s 311us/sample - loss: 0.6912 - accuracy: 0.6239 - val_loss: 0.6905 - val_accuracy: 0.6909
# Epoch 4/75
# 109/109 [==============================] - 0s 357us/sample - loss: 0.6885 - accuracy: 0.8899 - val_loss: 0.6872 - val_accuracy: 0.9091
# Epoch 5/75
# 109/109 [==============================] - 0s 384us/sample - loss: 0.6835 - accuracy: 0.9633 - val_loss: 0.6814 - val_accuracy: 0.9091
# Epoch 6/75
# 109/109 [==============================] - ETA: 0s - loss: 0.6781 - accuracy: 1.00 - 0s 339us/sample - loss: 0.6748 - accuracy: 0.9633 - val_loss: 0.6718 - val_accuracy: 0.9455
# Epoch 7/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.6619 - accuracy: 0.9633 - val_loss: 0.6572 - val_accuracy: 0.9455
# Epoch 8/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.6425 - accuracy: 0.9633 - val_loss: 0.6375 - val_accuracy: 0.9455
# Epoch 9/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.6174 - accuracy: 0.9633 - val_loss: 0.6115 - val_accuracy: 0.9636
# Epoch 10/75
# 109/109 [==============================] - 0s 320us/sample - loss: 0.5849 - accuracy: 0.9725 - val_loss: 0.5803 - val_accuracy: 0.9636
# Epoch 11/75
# 109/109 [==============================] - 0s 357us/sample - loss: 0.5474 - accuracy: 0.9725 - val_loss: 0.5440 - val_accuracy: 0.9636
# Epoch 12/75
# 109/109 [==============================] - 0s 485us/sample - loss: 0.5061 - accuracy: 0.9725 - val_loss: 0.5043 - val_accuracy: 0.9636
# Epoch 13/75
# 109/109 [==============================] - 0s 375us/sample - loss: 0.4617 - accuracy: 0.9725 - val_loss: 0.4644 - val_accuracy: 0.9636
# Epoch 14/75
# 109/109 [==============================] - 0s 311us/sample - loss: 0.4208 - accuracy: 0.9725 - val_loss: 0.4243 - val_accuracy: 0.9636
# Epoch 15/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.3800 - accuracy: 0.9725 - val_loss: 0.3874 - val_accuracy: 0.9636
# Epoch 16/75
# 109/109 [==============================] - 0s 375us/sample - loss: 0.3442 - accuracy: 0.9725 - val_loss: 0.3531 - val_accuracy: 0.9636
# Epoch 17/75
# 109/109 [==============================] - 0s 284us/sample - loss: 0.3120 - accuracy: 0.9725 - val_loss: 0.3214 - val_accuracy: 0.9636
# Epoch 18/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.2815 - accuracy: 0.9725 - val_loss: 0.2938 - val_accuracy: 0.9636
# Epoch 19/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.2553 - accuracy: 0.9817 - val_loss: 0.2681 - val_accuracy: 0.9636
# Epoch 20/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.2309 - accuracy: 0.9817 - val_loss: 0.2455 - val_accuracy: 0.9636
# Epoch 21/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.2092 - accuracy: 0.9817 - val_loss: 0.2254 - val_accuracy: 0.9636
# Epoch 22/75
# 109/109 [==============================] - 0s 362us/sample - loss: 0.1897 - accuracy: 0.9817 - val_loss: 0.2069 - val_accuracy: 0.9455
# Epoch 23/75
# 109/109 [==============================] - 0s 302us/sample - loss: 0.1725 - accuracy: 0.9817 - val_loss: 0.1905 - val_accuracy: 0.9455
# Epoch 24/75
# 109/109 [==============================] - 0s 311us/sample - loss: 0.1565 - accuracy: 0.9817 - val_loss: 0.1761 - val_accuracy: 0.9455
# Epoch 25/75
# 109/109 [==============================] - 0s 325us/sample - loss: 0.1426 - accuracy: 0.9817 - val_loss: 0.1638 - val_accuracy: 0.9455
# Epoch 26/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.1305 - accuracy: 0.9817 - val_loss: 0.1529 - val_accuracy: 0.9455
# Epoch 27/75
# 109/109 [==============================] - 0s 293us/sample - loss: 0.1199 - accuracy: 0.9817 - val_loss: 0.1433 - val_accuracy: 0.9455
# Epoch 28/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.1102 - accuracy: 0.9817 - val_loss: 0.1351 - val_accuracy: 0.9455
# Epoch 29/75
# 109/109 [==============================] - 0s 293us/sample - loss: 0.1018 - accuracy: 0.9817 - val_loss: 0.1277 - val_accuracy: 0.9455
# Epoch 30/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.0943 - accuracy: 0.9817 - val_loss: 0.1213 - val_accuracy: 0.9455
# Epoch 31/75
# 109/109 [==============================] - 0s 302us/sample - loss: 0.0877 - accuracy: 0.9817 - val_loss: 0.1158 - val_accuracy: 0.9455
# Epoch 32/75
# 109/109 [==============================] - 0s 293us/sample - loss: 0.0820 - accuracy: 0.9817 - val_loss: 0.1105 - val_accuracy: 0.9455
# Epoch 33/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.0765 - accuracy: 0.9817 - val_loss: 0.1059 - val_accuracy: 0.9455
# Epoch 34/75
# 109/109 [==============================] - 0s 293us/sample - loss: 0.0719 - accuracy: 0.9817 - val_loss: 0.1020 - val_accuracy: 0.9455
# Epoch 35/75
# 109/109 [==============================] - 0s 320us/sample - loss: 0.0674 - accuracy: 0.9908 - val_loss: 0.0983 - val_accuracy: 0.9636
# Epoch 36/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0633 - accuracy: 0.9908 - val_loss: 0.0950 - val_accuracy: 0.9636
# Epoch 37/75
# 109/109 [==============================] - 0s 320us/sample - loss: 0.0599 - accuracy: 0.9908 - val_loss: 0.0920 - val_accuracy: 0.9636
# Epoch 38/75
# 109/109 [==============================] - 0s 371us/sample - loss: 0.0565 - accuracy: 0.9908 - val_loss: 0.0892 - val_accuracy: 0.9636
# Epoch 39/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.0534 - accuracy: 0.9908 - val_loss: 0.0867 - val_accuracy: 0.9636
# Epoch 40/75
# 109/109 [==============================] - 0s 320us/sample - loss: 0.0506 - accuracy: 0.9908 - val_loss: 0.0845 - val_accuracy: 0.9636
# Epoch 41/75
# 109/109 [==============================] - 0s 343us/sample - loss: 0.0479 - accuracy: 0.9908 - val_loss: 0.0824 - val_accuracy: 0.9636
# Epoch 42/75
# 109/109 [==============================] - 0s 320us/sample - loss: 0.0457 - accuracy: 0.9908 - val_loss: 0.0804 - val_accuracy: 0.9636
# Epoch 43/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0432 - accuracy: 0.9908 - val_loss: 0.0787 - val_accuracy: 0.9636
# Epoch 44/75
# 109/109 [==============================] - 0s 352us/sample - loss: 0.0413 - accuracy: 0.9908 - val_loss: 0.0771 - val_accuracy: 0.9636
# Epoch 45/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.0394 - accuracy: 0.9908 - val_loss: 0.0756 - val_accuracy: 0.9636
# Epoch 46/75
# 109/109 [==============================] - 0s 325us/sample - loss: 0.0373 - accuracy: 0.9908 - val_loss: 0.0743 - val_accuracy: 0.9636
# Epoch 47/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.0357 - accuracy: 0.9908 - val_loss: 0.0731 - val_accuracy: 0.9636
# Epoch 48/75
# 109/109 [==============================] - 0s 366us/sample - loss: 0.0340 - accuracy: 0.9908 - val_loss: 0.0719 - val_accuracy: 0.9636
# Epoch 49/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0325 - accuracy: 0.9908 - val_loss: 0.0709 - val_accuracy: 0.9636
# Epoch 50/75
# 109/109 [==============================] - 0s 357us/sample - loss: 0.0310 - accuracy: 0.9908 - val_loss: 0.0700 - val_accuracy: 0.9636
# Epoch 51/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.0298 - accuracy: 0.9908 - val_loss: 0.0691 - val_accuracy: 0.9636
# Epoch 52/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0283 - accuracy: 0.9908 - val_loss: 0.0683 - val_accuracy: 0.9636
# Epoch 53/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.0272 - accuracy: 0.9908 - val_loss: 0.0675 - val_accuracy: 0.9636
# Epoch 54/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0260 - accuracy: 0.9908 - val_loss: 0.0668 - val_accuracy: 0.9636
# Epoch 55/75
# 109/109 [==============================] - 0s 366us/sample - loss: 0.0249 - accuracy: 0.9908 - val_loss: 0.0661 - val_accuracy: 0.9636
# Epoch 56/75
# 109/109 [==============================] - 0s 293us/sample - loss: 0.0239 - accuracy: 0.9908 - val_loss: 0.0655 - val_accuracy: 0.9636
# Epoch 57/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.0229 - accuracy: 0.9908 - val_loss: 0.0649 - val_accuracy: 0.9636
# Epoch 58/75
# 109/109 [==============================] - 0s 421us/sample - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9636
# Epoch 59/75
# 109/109 [==============================] - 0s 512us/sample - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9636
# Epoch 60/75
# 109/109 [==============================] - 0s 320us/sample - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9636
# Epoch 61/75
# 109/109 [==============================] - 0s 302us/sample - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9636
# Epoch 62/75
# 109/109 [==============================] - 0s 403us/sample - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9636
# Epoch 63/75
# 109/109 [==============================] - 0s 412us/sample - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9636
# Epoch 64/75
# 109/109 [==============================] - 0s 339us/sample - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9636
# Epoch 65/75
# 109/109 [==============================] - 0s 366us/sample - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9636
# Epoch 66/75
# 109/109 [==============================] - 0s 293us/sample - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9636
# Epoch 67/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9636
# Epoch 68/75
# 109/109 [==============================] - 0s 357us/sample - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9636
# Epoch 69/75
# 109/109 [==============================] - 0s 371us/sample - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9636
# Epoch 70/75
# 109/109 [==============================] - 0s 393us/sample - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9636
# Epoch 71/75
# 109/109 [==============================] - 0s 325us/sample - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9636
# Epoch 72/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9636
# Epoch 73/75
# 109/109 [==============================] - 0s 329us/sample - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9818
# Epoch 74/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9818
# Epoch 75/75
# 109/109 [==============================] - 0s 348us/sample - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9818
# Train on 106 samples, validate on 53 samples
# Epoch 1/75
# 106/106 [==============================] - 1s 7ms/sample - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4151
# Epoch 2/75
# 106/106 [==============================] - 0s 254us/sample - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.4340
# Epoch 3/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.6928 - accuracy: 0.6415 - val_loss: 0.6926 - val_accuracy: 0.8679
# Epoch 4/75
# 106/106 [==============================] - 0s 301us/sample - loss: 0.6922 - accuracy: 0.8868 - val_loss: 0.6916 - val_accuracy: 0.8868
# Epoch 5/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.6909 - accuracy: 0.9151 - val_loss: 0.6894 - val_accuracy: 0.8113
# Epoch 6/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.6884 - accuracy: 0.8679 - val_loss: 0.6855 - val_accuracy: 0.8113
# Epoch 7/75
# 106/106 [==============================] - 0s 292us/sample - loss: 0.6840 - accuracy: 0.8868 - val_loss: 0.6788 - val_accuracy: 0.7925
# Epoch 8/75
# 106/106 [==============================] - 0s 292us/sample - loss: 0.6761 - accuracy: 0.9340 - val_loss: 0.6690 - val_accuracy: 0.8302
# Epoch 9/75
# 106/106 [==============================] - 0s 306us/sample - loss: 0.6648 - accuracy: 0.9434 - val_loss: 0.6550 - val_accuracy: 0.8679
# Epoch 10/75
# 106/106 [==============================] - 0s 273us/sample - loss: 0.6500 - accuracy: 0.9434 - val_loss: 0.6363 - val_accuracy: 0.8679
# Epoch 11/75
# 106/106 [==============================] - 0s 301us/sample - loss: 0.6299 - accuracy: 0.9528 - val_loss: 0.6144 - val_accuracy: 0.8679
# Epoch 12/75
# 106/106 [==============================] - 0s 292us/sample - loss: 0.6070 - accuracy: 0.9528 - val_loss: 0.5882 - val_accuracy: 0.8679
# Epoch 13/75
# 106/106 [==============================] - 0s 315us/sample - loss: 0.5800 - accuracy: 0.9528 - val_loss: 0.5607 - val_accuracy: 0.8679
# Epoch 14/75
# 106/106 [==============================] - 0s 339us/sample - loss: 0.5519 - accuracy: 0.9528 - val_loss: 0.5302 - val_accuracy: 0.8679
# Epoch 15/75
# 106/106 [==============================] - 0s 301us/sample - loss: 0.5211 - accuracy: 0.9623 - val_loss: 0.5006 - val_accuracy: 0.8868
# Epoch 16/75
# 106/106 [==============================] - 0s 358us/sample - loss: 0.4906 - accuracy: 0.9623 - val_loss: 0.4716 - val_accuracy: 0.8868
# Epoch 17/75
# 106/106 [==============================] - 0s 310us/sample - loss: 0.4597 - accuracy: 0.9623 - val_loss: 0.4450 - val_accuracy: 0.8868
# Epoch 18/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.4310 - accuracy: 0.9623 - val_loss: 0.4202 - val_accuracy: 0.8868
# Epoch 19/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.4028 - accuracy: 0.9623 - val_loss: 0.3978 - val_accuracy: 0.8868
# Epoch 20/75
# 106/106 [==============================] - 0s 292us/sample - loss: 0.3765 - accuracy: 0.9717 - val_loss: 0.3766 - val_accuracy: 0.9057
# Epoch 21/75
# 106/106 [==============================] - 0s 301us/sample - loss: 0.3517 - accuracy: 0.9717 - val_loss: 0.3587 - val_accuracy: 0.9057
# Epoch 22/75
# 106/106 [==============================] - 0s 358us/sample - loss: 0.3287 - accuracy: 0.9717 - val_loss: 0.3412 - val_accuracy: 0.9057
# Epoch 23/75
# 106/106 [==============================] - 0s 311us/sample - loss: 0.3066 - accuracy: 0.9717 - val_loss: 0.3259 - val_accuracy: 0.9057
# Epoch 24/75
# 106/106 [==============================] - 0s 301us/sample - loss: 0.2860 - accuracy: 0.9717 - val_loss: 0.3122 - val_accuracy: 0.8868
# Epoch 25/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.2665 - accuracy: 0.9811 - val_loss: 0.2982 - val_accuracy: 0.9057
# Epoch 26/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.2479 - accuracy: 0.9811 - val_loss: 0.2863 - val_accuracy: 0.9057
# Epoch 27/75
# 106/106 [==============================] - 0s 325us/sample - loss: 0.2304 - accuracy: 0.9811 - val_loss: 0.2747 - val_accuracy: 0.9057
# Epoch 28/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.2136 - accuracy: 0.9811 - val_loss: 0.2646 - val_accuracy: 0.9057
# Epoch 29/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.1985 - accuracy: 0.9906 - val_loss: 0.2532 - val_accuracy: 0.9623
# Epoch 30/75
# 106/106 [==============================] - 0s 282us/sample - loss: 0.1847 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9623
# Epoch 31/75
# 106/106 [==============================] - 0s 292us/sample - loss: 0.1711 - accuracy: 1.0000 - val_loss: 0.2380 - val_accuracy: 0.9434
# Epoch 32/75
# 106/106 [==============================] - 0s 339us/sample - loss: 0.1593 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.9623
# Epoch 33/75
# 106/106 [==============================] - 0s 282us/sample - loss: 0.1486 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9434
# Epoch 34/75
# 106/106 [==============================] - 0s 358us/sample - loss: 0.1384 - accuracy: 1.0000 - val_loss: 0.2179 - val_accuracy: 0.9623
# Epoch 35/75
# 106/106 [==============================] - 0s 301us/sample - loss: 0.1289 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9623
# Epoch 36/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.1204 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9623
# Epoch 37/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.1128 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9623
# Epoch 38/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.1059 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9623
# Epoch 39/75
# 106/106 [==============================] - 0s 358us/sample - loss: 0.0996 - accuracy: 1.0000 - val_loss: 0.1937 - val_accuracy: 0.9623
# Epoch 40/75
# 106/106 [==============================] - 0s 339us/sample - loss: 0.0937 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9623
# Epoch 41/75
# 106/106 [==============================] - 0s 358us/sample - loss: 0.0883 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9623
# Epoch 42/75
# 106/106 [==============================] - 0s 367us/sample - loss: 0.0836 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9623
# Epoch 43/75
# 106/106 [==============================] - 0s 273us/sample - loss: 0.0792 - accuracy: 1.0000 - val_loss: 0.1834 - val_accuracy: 0.9623
# Epoch 44/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.0752 - accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.9623
# Epoch 45/75
# 106/106 [==============================] - 0s 367us/sample - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.1798 - val_accuracy: 0.9623
# Epoch 46/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.0680 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9623
# Epoch 47/75
# 106/106 [==============================] - 0s 339us/sample - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9623
# Epoch 48/75
# 106/106 [==============================] - 0s 348us/sample - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9623
# Epoch 49/75
# 106/106 [==============================] - 0s 376us/sample - loss: 0.0591 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9623
# Epoch 50/75
# 106/106 [==============================] - 0s 348us/sample - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.1745 - val_accuracy: 0.9623
# Epoch 51/75
# 106/106 [==============================] - 0s 357us/sample - loss: 0.0542 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9623
# Epoch 52/75
# 106/106 [==============================] - 0s 348us/sample - loss: 0.0518 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9623
# Epoch 53/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.0499 - accuracy: 1.0000 - val_loss: 0.1718 - val_accuracy: 0.9623
# Epoch 54/75
# 106/106 [==============================] - 0s 358us/sample - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9623
# Epoch 55/75
# 106/106 [==============================] - 0s 292us/sample - loss: 0.0463 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9623
# Epoch 56/75
# 106/106 [==============================] - 0s 334us/sample - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9623
# Epoch 57/75
# 106/106 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 1.00 - 0s 310us/sample - loss: 0.0428 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9623
# Epoch 58/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.0412 - accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9434
# Epoch 59/75
# 106/106 [==============================] - 0s 344us/sample - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.1718 - val_accuracy: 0.9434
# Epoch 60/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.0385 - accuracy: 1.0000 - val_loss: 0.1718 - val_accuracy: 0.9434
# Epoch 61/75
# 106/106 [==============================] - 0s 339us/sample - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.1707 - val_accuracy: 0.9434
# Epoch 62/75
# 106/106 [==============================] - 0s 348us/sample - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9434
# Epoch 63/75
# 106/106 [==============================] - 0s 348us/sample - loss: 0.0349 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9434
# Epoch 64/75
# 106/106 [==============================] - 0s 355us/sample - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.1708 - val_accuracy: 0.9434
# Epoch 65/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9434
# Epoch 66/75
# 106/106 [==============================] - 0s 329us/sample - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 0.9434
# Epoch 67/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9434
# Epoch 68/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9434
# Epoch 69/75
# 106/106 [==============================] - 0s 320us/sample - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9434
# Epoch 70/75
# 106/106 [==============================] - 0s 348us/sample - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9434
# Epoch 71/75
# 106/106 [==============================] - 0s 367us/sample - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9434
# Epoch 72/75
# 106/106 [==============================] - 0s 339us/sample - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.1741 - val_accuracy: 0.9434
# Epoch 73/75
# 106/106 [==============================] - 0s 339us/sample - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.1733 - val_accuracy: 0.9434
# Epoch 74/75
# 106/106 [==============================] - 0s 292us/sample - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.1734 - val_accuracy: 0.9434
# Epoch 75/75
# 106/106 [==============================] - 0s 315us/sample - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9434

# %%
pwd
# Out:
# 'C:\\Users\\Canon\\Desktop\\Final project\\Final Tk'

# %%
titanic_data = pd.read_csv("malariaF.csv")

# %%
titanic_data.isnull().sum()
# Out:
# recurrent fever    0
# chills             0
# sweating           0
# vomiting           0
# pallor             0
# headache           0
# abdomen pain       0
# fatigue            0
# weight loss        0
# breathlessness     0
# oedema             0
# malaria            0
# dtype: int64

# %%
data.dropna(inplace=True)
